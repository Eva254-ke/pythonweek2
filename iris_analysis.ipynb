# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# Task 1: Load and Explore the Dataset
try:
    # Load the Iris dataset
    iris = load_iris()

    # Convert to a pandas DataFrame
    iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

    # Add the target (species) as a categorical column
    iris_df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

    # Display the first few rows
    print("First 5 rows of the dataset:")
    print(iris_df.head())

    # Explore the structure of the dataset
    print("\nDataset Information:")
    iris_df.info()

    # Check for missing values
    print("\nMissing Values:")
    print(iris_df.isnull().sum())

except Exception as e:
    print(f"An error occurred while loading the dataset: {e}")

# Task 2: Basic Data Analysis
try:
    # Descriptive statistics for numerical columns
    print("\nDescriptive Statistics:")
    print(iris_df.describe())

    # Grouping and calculating means by species
    grouped_means = iris_df.groupby('species').mean()
    print("\nGrouped Means by Species:")
    print(grouped_means)

    # Observations
    print("\nObservations:")
    print("- Virginica species has the largest average sepal length and petal width.")
    print("- Setosa species has significantly smaller petal dimensions compared to others.")

except Exception as e:
    print(f"An error occurred during analysis: {e}")

# Task 3: Data Visualization
try:
    sns.set(style="whitegrid")
    plt.figure(figsize=(12, 8))

    # Line Chart: Simulating trends over time by introducing a synthetic time variable
    iris_df['time'] = range(1, len(iris_df) + 1)
    plt.subplot(2, 2, 1)
    sns.lineplot(x='time', y='sepal length (cm)', hue='species', data=iris_df, marker="o")
    plt.title("Sepal Length Over Time")
    plt.xlabel("Time")
    plt.ylabel("Sepal Length (cm)")

    # Bar Chart: Average Sepal Length by Species
    plt.subplot(2, 2, 2)
    sns.barplot(x='species', y='sepal length (cm)', data=iris_df, ci=None, palette="viridis")
    plt.title("Average Sepal Length by Species")
    plt.xlabel("Species")
    plt.ylabel("Average Sepal Length (cm)")

    # Histogram: Distribution of Petal Length
    plt.subplot(2, 2, 3)
    sns.histplot(iris_df['petal length (cm)'], kde=True, bins=15, color="skyblue")
    plt.title("Distribution of Petal Length")
    plt.xlabel("Petal Length (cm)")
    plt.ylabel("Frequency")

    # Scatter Plot: Sepal Length vs Petal Width
    plt.subplot(2, 2, 4)
    sns.scatterplot(x='sepal length (cm)', y='petal width (cm)', hue='species', data=iris_df, palette="deep")
    plt.title("Sepal Length vs Petal Width")
    plt.xlabel("Sepal Length (cm)")
    plt.ylabel("Petal Width (cm)")

    # Adjust layout and show the plots
    plt.tight_layout()
    plt.show()

except Exception as e:
    print(f"An error occurred during visualization: {e}")
# Out:
# First 5 rows of the dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB
#
# Missing Values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64
#
# Descriptive Statistics:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
#
# Grouped Means by Species:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026
#
# Observations:
# - Virginica species has the largest average sepal length and petal width.
# - Setosa species has significantly smaller petal dimensions compared to others.
# <ipython-input-1-fd59771c552c>:41: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_means = iris_df.groupby('species').mean()
# <ipython-input-1-fd59771c552c>:68: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='species', y='sepal length (cm)', data=iris_df, ci=None, palette="viridis")
# <ipython-input-1-fd59771c552c>:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species', y='sepal length (cm)', data=iris_df, ci=None, palette="viridis")
